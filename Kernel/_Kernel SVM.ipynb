# %%
import numpy as ap
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
##RBF 
from sklearn.svm import SVC
classifier=SVC(kernel="rbf",random_state=0)
classifier.fit(x_train,y_train)
# Out:
# SVC(random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %%
print(classifier.predict(sc.transform([[30,87000]])))
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[54  4]
#  [ 1 21]]
# 0.9375

# %%
import numpy as np
from matplotlib.colors import ListedColormap
x_set,y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_test,y_test
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
##polynomial SVM
from sklearn.svm import SVC
classifier1=SVC(kernel="poly",random_state=0,degree=10)
classifier1.fit(x_train,y_train)
# Out:
# SVC(degree=10, kernel='poly', random_state=0)

# %%
y_pred=classifier1.predict(x_test)

# %%
print(classifier1.predict(sc.transform([[30,87000]])))
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[57  1]
#  [11 11]]
# 0.85

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier1.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_test,y_test
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier1.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
##Sigmoid SVM
from sklearn.svm import SVC
classifier2=SVC(kernel="sigmoid",random_state=0)
classifier2.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid', random_state=0)

# %%
y_pred=classifier2.predict(x_test)

# %%
print(classifier2.predict(sc.transform([[30,87000]])))
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[42 16]
#  [ 8 14]]
# 0.7

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier2.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_test,y_test
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier2.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
##Linear SVM
from sklearn.svm import SVC
classifier3=SVC(kernel="linear",random_state=0)
classifier3.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred=classifier3.predict(x_test)

# %%
print(classifier3.predict(sc.transform([[30,87000]])))
# Out:
# [0]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[52  6]
#  [ 3 19]]
# 0.8875

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier3.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from matplotlib.colors import ListedColormap
x_set,y_set=x_test,y_test
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min() -1,stop=x_set[:,0].max() +1,step=0.25),
  np.arange(start=x_set[:,1].min() -1,stop=x_set[:,1].max() +1,step=0.25))
probs=classifier3.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape)
plt.contourf(x1,x2,probs,alpha=0.75,cmap=ListedColormap(("blue","green")))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j, 0],x_set[y_set==j, 1],c=ListedColormap(("blue","green"))(i),label=j)
plt.title(" Kernel SVM")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
